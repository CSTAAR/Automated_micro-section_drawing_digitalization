# %%
"""
Script 4: LayerAnnotator

Description:
This script provides a semi-automated interface to manually assign layer numbers to polygon geometries
extracted from georeferenced stratigraphic section drawings. It overlays each polygon on its corresponding
section drawing (based on template matching and ROI extraction), and allows the user to:

- Enter the correct layer number (`Layer_No`)
- Assign the `Section_ID` based on the filename
- Mark all layers in a section as valid or erroneous (`Error` column)

After manual annotation, the script creates one bounding box for each section/raster based on the retained
annotated polygon geometries. These bounding boxes are saved as a separate section-level shapefile and can
be used as section frames, spatial indices, or auxiliary geometries for GIS processing and visualisation.

The script does not overwrite the raw vectorisation output. Instead, it reads the raw polygon layer, saves
the manually annotated and validated layer polygons as a new shapefile, and then creates a separate
section-level bounding box layer from the annotated output.

To use this script correctly, the user must define the user settings below, including:
- input_folder:        path to the folder containing the rectified GeoTIFFs
- input_layer_path:    path to the raw polygon shapefile produced by the vectorisation script
- output_layer_path:   path where the annotated layer polygons will be saved
- output_box_shp_path:  path where the section-level bounding boxes will be saved
- template_path:       path to the scale-bar template used for ROI extraction
- roi_width:           width of the extracted ROI in pixels
- buffer_distance:     buffer added to each side of the section bounding box

The script uses a pre-existing shapefile that already contains the polygons and a 'Raster' column linking each polygon
to its source raster image. Visual verification of geometry placement is done through matplotlib overlays.

Notes:
- The template must match the scale bar appearance and size used in the dataset.
- Ensure the input shapefile contains a `Raster` column and valid polygon geometries.
- Ensure the shapefile contains or allows adding columns: `Layer_No`, `Section_ID`, `Error`.
- Polygons marked with Layer_No = 0 are removed from the annotated output shapefile before saving.
- Section bounding boxes are created only after annotation, using the retained annotated polygons.
- Bounding boxes preserve the section-level `Error` value, so sections marked as erroneous can be identified in GIS.
- The output is split into two layers: annotated stratigraphic polygons and section-level bounding boxes.
"""
import os
import time
import cv2
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, box
import rasterio
from rasterio.plot import reshape_as_image

# ---------------------------------------------
# USER SETTINGS (EDIT BEFORE RUNNING)
# ---------------------------------------------
input_folder = r"C:\path_to_input_folder" # Path to the folder containing the rectified GeoTIFFs
input_layer_path = r"path_to_input_layer_shp" #Path to the shapefile with polygon geometries and the "Raster" column
template_path = r"C:\path_to_template" #Image of the 1m scale bar used to locate the drawing area for ROI extraction
output_layer_path = r"path_to_output_layer_shp" #Path to the output shapefile with manually annotated and validated layer polygons
output_box_shp_path = r"C:\path_to_output_SECTION_ID_boxes_shp" #Path to the output shapefile with one bounding box per section/raster

roi_width = 900 # This defines how wide the cropped drawing area will be. Adjust based on the form layout.
scale_template_resize_factor = 2.35 # Must match the scale appearance in the rectified drawings. Try adjusting if template matching fails.
roi_x_offset_pixels = 0  # Optional horizontal offset (in pixels) applied to shift the ROI position further to the right of the scale bar. Use if the ROI is misaligned due to form variation.
buffer_distance = 0.25  # map units; if CRS is in meters, this means 0.25 m
# ---------------------------------------------
# FUNCTIONS
# ---------------------------------------------
def template_matching(img, template_path):
    """Locate the position of the scale bar in a raster image using template matching"""
    template = cv2.imread(template_path, 0)
    template = cv2.resize(template, (
        int(template.shape[1] * scale_template_resize_factor),
        int(template.shape[0] * scale_template_resize_factor)))
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    result = cv2.matchTemplate(img_gray, template, cv2.TM_CCOEFF_NORMED)
    _, _, _, max_loc = cv2.minMaxLoc(result)
    return max_loc, template.shape[::-1]

def extract_roi(img, scale_loc, scale_size, roi_width):
    """Extract the Region of Interest (ROI) to the right of the scale bar."""
    x, y = scale_loc
    t_w, t_h = scale_size
    roi_x = x + t_w + roi_x_offset_pixels
    roi_y = y
    roi = img[roi_y:roi_y + t_h, roi_x:roi_x + roi_width]
    return roi, (roi_x, roi_y, t_h, roi_width)

def overlay_geometry_on_roi(roi, geom, transform, roi_origin):
    """Plot a shapely polygon geometry overlaid on the ROI image for visual inspection."""
    fig, ax = plt.subplots(figsize=(5, 6))
    ax.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))

    # Transform polygon coordinates to image space
    inv_transform = ~transform
    roi_x, roi_y, _, _ = roi_origin

    if isinstance(geom, Polygon):
        x, y = geom.exterior.coords.xy
        px = []
        py = []
        for xi, yi in zip(x, y):
            col, row = inv_transform * (xi, yi)
            px.append(col - roi_x)
            py.append(row - roi_y)
        ax.plot(px, py, color='red', linewidth=2)

    ax.axis('off')
    plt.tight_layout()
    plt.show()

def create_section_boxes(
    gdf,
    output_path,
    raster_col="Raster",
    section_col="Section_ID"
):
    """
    Create one bounding box for each raster/section based on annotated polygon geometries.

    Bounding boxes are created from the already annotated and filtered GeoDataFrame.
    The global `buffer_distance` parameter is used to expand each box on all sides.
    The section-level Error value is preserved in the output.
    """

    if raster_col not in gdf.columns:
        raise ValueError(f"Missing required column: {raster_col}")

    if section_col not in gdf.columns:
        raise ValueError(f"Missing required column: {section_col}")

    if gdf.crs is None:
        print("Warning: input layer has no CRS. Buffer distance will still be applied in coordinate units.")

    # Remove invalid / empty geometries
    valid_gdf = gdf[gdf.geometry.notnull()].copy()
    valid_gdf = valid_gdf[~valid_gdf.geometry.is_empty].copy()

    bbox_records = []

    for raster_value, group in valid_gdf.groupby(raster_col):
        if group.empty:
            continue

        minx, miny, maxx, maxy = group.total_bounds

        # Expand bounding box by the global buffer_distance on each side
        minx -= buffer_distance
        miny -= buffer_distance
        maxx += buffer_distance
        maxy += buffer_distance

        bbox_geom = box(minx, miny, maxx, maxy)

        # Prefer existing Section_ID from annotated polygons
        section_values = group[section_col].dropna().unique()

        if len(section_values) > 0:
            section_id = str(section_values[0])
        else:
            section_id = str(raster_value).replace("CS_", "")

        # Preserve section-level Error information
        if "Error" in group.columns:
            error_values = group["Error"].dropna().unique()
            error_value = error_values[0] if len(error_values) > 0 else None
        else:
            error_value = None

        bbox_records.append({
            section_col: section_id,
            raster_col: str(raster_value),
            "Error": error_value,
            "geometry": bbox_geom
        })

    section_gdf = gpd.GeoDataFrame(
        bbox_records,
        geometry="geometry",
        crs=valid_gdf.crs
    )

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    section_gdf.to_file(output_path, driver="ESRI Shapefile")

    print(f"Created section bounding boxes: {output_path}")
    print(f"Number of boxes: {len(section_gdf)}")
    print(f"One box was created for each unique value in '{raster_col}'.")
# ---------------------------------------------
# MAIN PROCESS
# ---------------------------------------------
def main():
    start_time = time.time()
#    layer_records = []

    gdf = gpd.read_file(input_layer_path)

    # Add columns if not exist
    for col in ["Layer_No", "Section_ID", "Error"]:
        if col not in gdf.columns:
            gdf[col] = None

    for filename in sorted(os.listdir(input_folder)):
        if not filename.endswith(".tif"):
            continue

        raster_name = os.path.splitext(filename)[0]
        matching_polys = gdf[gdf["Raster"] == raster_name]

        if matching_polys.empty:
            print(f"No polygons found for raster: {raster_name}")
            continue

        print(f"Processing {raster_name} with {len(matching_polys)} layers")

        raster_path = os.path.join(input_folder, filename)
        
        with rasterio.open(raster_path) as src:
            transform = src.transform
            img = reshape_as_image(src.read())
            if img.shape[2] == 1:
                img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

        scale_loc, scale_size = template_matching(img, template_path)
        roi, roi_origin = extract_roi(img, scale_loc, scale_size, roi_width)

        for idx in matching_polys.index:
            polygon = gdf.loc[idx, "geometry"]
            overlay_geometry_on_roi(roi, polygon, transform, roi_origin)

            while True:
                layer_input = input("Layer number (or press Enter to skip): ").strip()
                if layer_input == "":
                    gdf.loc[idx, "Layer_No"] = 0
                    break
                elif layer_input.isdigit():
                    gdf.loc[idx, "Layer_No"] = int(layer_input)
                    break
                else:
                    print("Invalid input. Please enter a number.")

            section_id = ''.join(filter(str.isdigit, raster_name))
            gdf.loc[idx, "Section_ID"] = section_id

        confirm = input(f"Confirm {raster_name} (Enter = OK, 'e' = mark all as error): ").strip().lower()
        if confirm == 'e':
            gdf.loc[gdf["Raster"] == raster_name, "Error"] = "Error"
        else:
            gdf.loc[gdf["Raster"] == raster_name, "Error"] = "OK"

    # Remove polygons with Layer_No = 0
    gdf = gdf[gdf["Layer_No"] != 0]

    # Save annotated layer polygons
    gdf.to_file(output_layer_path, driver="ESRI Shapefile")
    elapsed = time.time() - start_time
    print(f"Updated and saved shapefile: {output_layer_path}")
    print(f"Elapsed time: {elapsed:.2f} seconds")
    
    # Create bounding boxes
    create_section_boxes(
    gdf=gdf,
    output_path=output_box_shp_path,
    raster_col="Raster",
    section_col="Section_ID"
)

if __name__ == "__main__":
    main()
